# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cc = pd.read_csv("E:\Downlload\CC GENERAL.csv")

# %%
cc
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
cc.shape
# Out:
# (8950, 18)

# %%
cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
cc = cc.drop(['CUST_ID'],axis=1)

# %%
cc.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
plt.rcParams["figure.figsize"] = 20,18
cc.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024A72E080C8>,
# ...
#       dtype=object)

# %%
cc = np.log1p(cc)
cc.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024A7423CEC8>,
# ...
#       dtype=object)

# %%
cc
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     3.735304           0.597837   4.568506          0.000000
# 1     8.071989           0.646627   0.000000          0.000000
# 2     7.822504           0.693147   6.651791          6.651791
# 3     7.419183           0.492477   7.313220          7.313220
# 4     6.707735           0.693147   2.833213          2.833213
# ...        ...                ...        ...               ...
# 8945  3.384170           0.693147   5.677165          0.000000
# 8946  3.004851           0.693147   5.707110          0.000000
# 8947  3.194529           0.606136   4.979489          0.000000
# 8948  2.671218           0.606136   0.000000          0.000000
# 8949  5.923475           0.510826   6.997824          6.997824
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   4.568506      0.000000             0.154151
# 1                   0.000000      8.770896             0.000000
# ...

# %%
cc.isna().sum().sum()
# Out:
# 314

# %%
cc = cc.dropna()

# %%
cc.isna().sum().sum()
# Out:
# 0

# %%
cc
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     3.735304           0.597837   4.568506          0.000000
# 1     8.071989           0.646627   0.000000          0.000000
# 2     7.822504           0.693147   6.651791          6.651791
# 4     6.707735           0.693147   2.833213          2.833213
# 5     7.501540           0.693147   7.196147          0.000000
# ...        ...                ...        ...               ...
# 8943  1.927413           0.405465   3.086487          3.086487
# 8945  3.384170           0.693147   5.677165          0.000000
# 8947  3.194529           0.606136   4.979489          0.000000
# 8948  2.671218           0.606136   0.000000          0.000000
# 8949  5.923475           0.510826   6.997824          6.997824
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   4.568506      0.000000             0.154151
# 1                   0.000000      8.770896             0.000000
# ...

# %%
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()

# %%
Scaled_cc = cc.apply(lambda x:(x.astype(float) - min(x))/(max(x)-min(x)), axis = 0)

# %%
Scaled_cc
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     0.002148           0.818182   0.001945          0.000000
# 1     0.168169           0.909091   0.000000          0.000000
# 2     0.131026           1.000000   0.015766          0.018968
# 4     0.042940           1.000000   0.000326          0.000393
# 5     0.095038           1.000000   0.027188          0.000000
# ...        ...                ...        ...               ...
# 8943  0.000308           0.500000   0.000426          0.000513
# 8945  0.001496           1.000000   0.005936          0.000000
# 8947  0.001229           0.833333   0.002945          0.000000
# 8948  0.000707           0.833333   0.000000          0.000000
# 8949  0.019572           0.666667   0.022293          0.026821
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   0.004240      0.000000             0.166667
# 1                   0.000000      0.136685             0.000000
# ...

# %%
from sklearn.cluster import KMeans
plt.rcParams["figure.figsize"] = 10,8
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 500, n_init = 20, random_state = 0)
    kmeans.fit(Scaled_cc)
    wcss.append(kmeans.inertia_)
    
#Plotting the results onto a line graph, allowing us to observe 'The elbow'
plt.plot(range(1, 11), wcss)
plt.title('Optimum K for CC General')
plt.xlabel('Agrupaciones')
plt.ylabel('WCSS') #within cluster sum of squares
plt.show()

# %%
wcss
# Out:
# [10133.467271312842,
#  6291.049926389874,
#  5247.8926498964765,
#  4396.347937920243,
#  3908.688222844594,
#  3581.1513439518867,
#  3293.498603683889,
#  3046.6159938930728,
#  2881.6406176236833,
#  2732.2146056473093]

# %%
r =[]
for v in range(len(wcss)):
    if v+1 < len(wcss):
        r.append((wcss[v]-wcss[v+1])/(wcss[v]))
r
# Out:
# [0.37918091034848367,
#  0.16581608613810733,
#  0.1622641255805856,
#  0.11092382176337559,
#  0.08379713607711037,
#  0.08032409486234277,
#  0.07496059342933069,
#  0.05415036768666672,
#  0.05185449256319709]

# %%
kmeans = KMeans(n_clusters = 4, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(Scaled_cc)

# %%
centers = kmeans.cluster_centers_
print(centers)
# Out:
# [[0.10037551 0.98002204 0.06684285 0.06125394 0.03471812 0.0141633
#   0.90191373 0.83068022 0.46516882 0.06064189 0.01795284 0.11990291
#   0.22287406 0.0657486  0.00971128 0.25550418 0.96087889]
#  [0.08357052 0.94448489 0.02439434 0.00929851 0.03634974 0.01499943
#   0.87884582 0.13346523 0.82651106 0.06507565 0.02034957 0.06520395
#   0.13669041 0.03148711 0.01563182 0.0656809  0.93668357]
#  [0.0962227  0.86796228 0.00586224 0.00575832 0.00235199 0.03019133
#   0.13829335 0.08278375 0.05480822 0.13188853 0.03808123 0.00733386
#   0.1372059  0.0297935  0.01150628 0.03936741 0.91314772]
#  [0.00580366 0.78956259 0.02108607 0.00763686 0.03215783 0.00204293
#   0.7220311  0.10797114 0.63257021 0.00789277 0.00227072 0.04430418
#   0.13627699 0.02773929 0.00231078 0.81682748 0.87970062]]

# %%
new_labels = kmeans.labels_
new_labels
# Out:
# array([2, 2, 0, ..., 1, 2, 0])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
pca.fit(Scaled_cc)
features =pca.transform(Scaled_cc);
print(features.shape,new_labels.shape)
# Out:
# (8636, 3) (8636,)

# %%
new_labels=new_labels.reshape(-1,1)
new_labels.shape
# Out:
# (8636, 1)

# %%
new_data = pd.DataFrame(features)
new_data["y"]= new_labels
new_data.head()
# Out:
#           0         1         2  y
# 0 -0.492046 -0.106987 -0.024615  2
# 1 -0.620691 -0.030137  0.111544  2
# 2  0.291581  0.922922 -0.133906  0
# 3 -0.567819  0.023027 -0.070132  2
# 4  0.188140 -0.249456 -0.228906  1

# %%
def get_data(label,x):
    c = x[x["y"]==label]
    return c

# %%
c1 = get_data(0,new_data)
c2 =get_data(1,new_data)
c3 =get_data(2,new_data)
c4 =get_data(3,new_data)

# %%
data_list =[c1,c2,c3,c4]

# %%
legend =[]
for lbl in unique_labels1:
    sample = output1[output1[:,2]==lbl].transpose()
    plt.scatter(sample[0],sample[1])
    legend.append(lbl)
plt.legend(legend)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
c =0
for xyz in data_list:
    x = xyz[0].tolist()
    y = xyz[1].tolist()
    z = xyz[2].tolist()
    ax.scatter(x,y,z,s= 20, label =str(c))
    c = c+1
plt.legend(loc='upper left')
plt.show()
plt.savefig("dh.jpg")

# %%
import numpy as np
labels_t = new_labels.reshape(8636,1)
print(features.shape,new_labels.shape)
output1 = np.concatenate((features,labels_t),axis=1)
print(output1.shape)
unique_labels1 = set(new_labels); print(unique_labels1)
# Out:
# (8636, 2) (8636,)
# (8636, 3)
# {0, 1, 2, 3, 4}

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
Z = linkage(Scaled_cc, 'ward')
max_d = 7.08                

plt.figure(figsize=(25, 10))
plt.title('Credit Card  Clustering Dendrogram',fontsize=30)
plt.xlabel('Labels',fontsize=30)
plt.ylabel('distance',fontsize=30)
dendrogram(
    Z,
    truncate_mode='lastp',  
    p=100,                  
    leaf_rotation=30.,      
    leaf_font_size=8.,      
)
plt.axhline(y=max_d, c='k')
plt.show()

# %%
for lbl in unique_labels1:
    sample = output1[output1[:,2]==lbl]
    print(lbl,":", len(sample))
# Out:
# 0 : 2406
# 1 : 1905
# 2 : 1187
# 3 : 1781
# 4 : 1357

# %%
new_labels = pd.DataFrame(new_labels)
new_labels
# Out:
#       0
# 0     3
# 1     0
# 2     3
# 3     3
# 4     1
# ...  ..
# 8631  3
# 8632  1
# 8633  1
# 8634  0
# 8635  3
#
# [8636 rows x 1 columns]

# %%
c1=new_labels[new_labels == 3]
c1=c1.dropna()
c1=c1.reset_index(drop=True)
c1
# Out:
#         0
# 0     3.0
# 1     3.0
# 2     3.0
# 3     3.0
# 4     3.0
# ...   ...
# 1776  3.0
# 1777  3.0
# 1778  3.0
# 1779  3.0
# 1780  3.0
#
# [1781 rows x 1 columns]

# %%
def get_data(label,x):
    c = x[x[0 == ]]
